# %%
# run_tournament_v2_debug_fixed.py
"""
Run the full Farkle strategy tournament with multiprocessing,
queue-based logging, and resumable checkpoints.
"""
from __future__ import annotations

import logging
import logging.handlers
import multiprocessing as mp
import pickle
import sys
import time
from collections import Counter
from pathlib import Path
from typing import Tuple

import numpy as np

from farkle.simulation import generate_strategy_grid, _play_game
from farkle.stats import games_for_power


def short_vars(d: dict, max_len: int = 100) -> str:
    s = repr(d)
    return s if len(s) <= max_len else s[:max_len] + "…"

# ──────────────────────────────────────────────────────────────────────────────
# 0.--- Globals & tuning knobs
CHUNKSIZE       = 100          # tasks sent to each worker at a time
PROCESSES       = 16
MAXTASKS        = 50              # fork a fresh worker after this many tasks
REPORT_EVERY    = 100_000         # progress print interval
CHECKPOINT_FILE = Path("win_counter.chk")

# ──────────────────────────────────────────────────────────────────────────────
# 1.--- Set up root logger and handler (no debug() calls here yet)
DEBUG_FIRST_N = 10000   # change once; used by the filter below

class FirstNFilter(logging.Filter):
    """
    Let every unique call-site (file, lineno) speak `n` times, then silence it.
    Works no matter how tight the surrounding loop is.
    """
    def __init__(self, n: int = DEBUG_FIRST_N):
        super().__init__()
        self.n = n
        self.seen: Counter[Tuple[str, int]] = Counter()

    def filter(self, record: logging.LogRecord) -> bool:
        key = (record.pathname, record.lineno)
        self.seen[key] += 1
        return self.seen[key] <= self.n

# configure the root logger
root = logging.getLogger()             # grab root so *all* libraries inherit it
root.setLevel(logging.DEBUG)           # we really want to see DEBUG

handler = logging.StreamHandler(sys.stdout)  # print to stdout
handler.setFormatter(logging.Formatter(
        "%(asctime)s %(levelname)-5s %(filename)s:%(lineno)d | %(message)s",
        datefmt="%H:%M:%S"))
handler.addFilter(FirstNFilter(DEBUG_FIRST_N))

root.handlers[:] = [handler]            # replace any default handlers

# now that the handler is fully set up, we can safely grab “tournament” logger
log = logging.getLogger("tournament")
# No log.debug(...) here at module import time.

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s|%(processName)s|%(levelname)s|%(message)s",
    datefmt="%H:%M:%S"
)

# ──────────────────────────────────────────────────────────────────────────────
# 2.--- Strategy grid and powered sample size
strategies, meta = generate_strategy_grid()
meta["str_repr"] = [str(s) for s in strategies]

n_games_per_player = games_for_power(
    n_strategies=len(strategies),
    delta=0.03, alpha=0.025, power=0.90,
    method="bh", pairwise=True,
)
total_tasks = len(strategies) * n_games_per_player // 5  # == total games

log.info("n_games_per_player = %s, total tasks = %s", n_games_per_player, total_tasks)

# ──────────────────────────────────────────────────────────────────────────────


# ──────────────────────────────────────────────────────────────────────────────
# 5.--- Worker function
def _one(task):
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("reached _one  vars=%s", vars_snippet)
    seed, idxs = task
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("unpacked task in _one  vars=%s", vars_snippet)
    table = [strategies[i] for i in idxs]
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("constructed table in _one  vars=%s", vars_snippet)
    row = _play_game(seed, table, 10_000)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("completed _play_game in _one  vars=%s", vars_snippet)
    win = str(row[f"{row['winner']}_strategy"])
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("computed win in _one  vars=%s", vars_snippet)
    return win

# ──────────────────────────────────────────────────────────────────────────────
# 3.–6. Combined, memory-light task stream with resume support

def task_stream(already_done: int = 0):
    """
    Lazily yields (seed, idxs) for each game:
      - rep in [0..n_games_per_player)
      - permute strategies
      - take groups of 5 as one table
    Skips the first `already_done` tables in O(1), not by calling next() repeatedly.
    """
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("reached task_stream:  vars=%s", vars_snippet)
    num_strats = len(strategies)
    tables_per_rep = num_strats // 5

    # figure out where to start
    start_rep, start_table = divmod(already_done, tables_per_rep)

    perm_rng = np.random.default_rng(999)       # RNG for the permutations
    seed_rng = np.random.default_rng(1234)      # RNG for the per‐game seeds
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("assigned task_stream variables vars=%s", vars_snippet)

    for rep in range(start_rep, n_games_per_player):
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("entered loop in task_stream   vars=%s", vars_snippet)
        perm = perm_rng.permutation(num_strats)   # one new random order
        # if this is our first rep, skip up to start_table
        first_j = 5 * (start_table if rep == start_rep else 0)

        for j in range(first_j, num_strats, 5):
            # stop if not a full group of 5
            if j + 5 > num_strats:
                break
            idxs = tuple(int(x) for x in perm[j : j + 5])
            seed = int(seed_rng.integers(2**32))
            yield (seed, idxs)


# ──────────────────────────────────────────────────────────────────────────────
# 7.--- Checkpoint helpers
def save_checkpoint(counter: Counter, done: int):
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("reached save_checkpoint  vars=%s", vars_snippet)
    with CHECKPOINT_FILE.open("wb") as f:
        pickle.dump({"done": done, "counter": dict(counter)}, f)
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("pickle.dump completed in save_checkpoint  vars=%s", vars_snippet)
    log.info("Checkpoint saved at %s tasks.", done)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("exiting save_checkpoint  vars=%s", vars_snippet)

def load_checkpoint() -> tuple[int, Counter]:
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("reached load_checkpoint  vars=%s", vars_snippet)
    if not CHECKPOINT_FILE.exists():
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("load_checkpoint found no checkpoint file  vars=%s", vars_snippet)
        return 0, Counter()
    with CHECKPOINT_FILE.open("rb") as f:
        data = pickle.load(f)
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("pickle.load completed in load_checkpoint  vars=%s", vars_snippet)
    log.info("Checkpoint loaded: %s tasks finished previously.", data["done"])
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("exiting load_checkpoint with data  vars=%s", vars_snippet)
    return data["done"], Counter(data["counter"])

# ──────────────────────────────────────────────────────────────────────────────
# 8.--- Multiprocessing-friendly logging (single queue sink)
def _configure_worker_logging(queue):
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("reached _configure_worker_logging  vars=%s", vars_snippet)
    qh = logging.handlers.QueueHandler(queue)
    root = logging.getLogger()
    root.handlers.clear()
    root.setLevel(logging.DEBUG)
    root.addHandler(qh)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("configured worker logging handlers  vars=%s", vars_snippet)

def _listener_process(queue):
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("reached _listener_process  vars=%s", vars_snippet)
    h = logging.StreamHandler(sys.stdout)
    fmt = logging.Formatter("%(asctime)s|%(processName)s|%(levelname)s|%(message)s", "%H:%M:%S")
    h.setFormatter(fmt)
    root = logging.getLogger()
    root.addHandler(h)
    root.setLevel(logging.DEBUG)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("listener configured its handler  vars=%s", vars_snippet)
    while True:
        record = queue.get()
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("listener received record  vars=%s", vars_snippet)
        if record is None:
            vars_snippet = short_vars(locals(), 100)                 
            log.debug("listener received sentinel None  vars=%s", vars_snippet)
            break
        root.handle(record)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("listener exiting  vars=%s", vars_snippet)

# ──────────────────────────────────────────────────────────────────────────────
def main():
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("reached main  vars=%s", vars_snippet)
    already_done, win_counter = load_checkpoint()
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("after load_checkpoint in main  vars=%s", vars_snippet)

    if already_done >= total_tasks:
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("main early exit condition met  vars=%s", vars_snippet)
        log.warning("All %s tasks are already complete. Nothing to do!", total_tasks)
        return

    log_queue = mp.Queue()
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("created log_queue in main  vars=%s", vars_snippet)
    listener = mp.Process(target=_listener_process, args=(log_queue,), daemon=True)
    listener.start()
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("started listener process in main  vars=%s", vars_snippet)

    start_time = time.perf_counter()
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("recorded start_time in main  vars=%s", vars_snippet)
    done = already_done
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("initialized done counter in main  vars=%s", vars_snippet)

    with mp.Pool(
        processes=PROCESSES,
        maxtasksperchild=MAXTASKS,
        initializer=_configure_worker_logging,
        initargs=(log_queue,),
    ) as pool:
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("entered Pool context in main  vars=%s", vars_snippet)
        log.info("Pool started with %d workers.", PROCESSES)
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("logged pool start info in main  vars=%s", vars_snippet)
        stream = task_stream(already_done)
        vars_snippet = short_vars(locals(), 100)                 
        log.debug("created stream iterator in main  vars=%s", vars_snippet)

        for win in pool.imap_unordered(_one, stream, chunksize=CHUNKSIZE):
            vars_snippet = short_vars(locals(), 100)                 
            log.debug("received win from pool.imap_unordered  vars=%s", vars_snippet)
            win_counter[win] += 1
            vars_snippet = short_vars(locals(), 100)                 
            log.debug("updated win_counter in main loop  vars=%s", vars_snippet)
            done += 1
            vars_snippet = short_vars(locals(), 100)                 
            log.debug("incremented done in main loop  vars=%s", vars_snippet)

            if done % REPORT_EVERY == 0 or done == total_tasks:
                vars_snippet = short_vars(locals(), 100)                 
                log.debug("about to compute progress in main loop  vars=%s", vars_snippet)
                pct = 100 * done / total_tasks
                hrs = (time.perf_counter() - start_time) / 3600
                log.info("[%10d / %10d]  %6.2f %%  %6.2f h elapsed", done, total_tasks, pct, hrs)
                vars_snippet = short_vars(locals(), 100)                 
                log.debug("about to save checkpoint in main loop  vars=%s", vars_snippet)
                save_checkpoint(win_counter, done)
                vars_snippet = short_vars(locals(), 100)                 
                log.debug("saved checkpoint in main loop  vars=%s", vars_snippet)

        vars_snippet = short_vars(locals(), 100)                 
        log.debug("exited for loop in main  vars=%s", vars_snippet)

    # tell listener to finish
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("sending sentinel to listener  vars=%s", vars_snippet)
    log_queue.put(None)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("sent sentinel to listener  vars=%s", vars_snippet)
    listener.join()
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("listener joined in main  vars=%s", vars_snippet)

    # final dump + CSV
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("about to save final checkpoint  vars=%s", vars_snippet)
    save_checkpoint(win_counter, done)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("saved final checkpoint  vars=%s", vars_snippet)

    summary = (
        meta[["strategy_idx", "str_repr"]]
        .assign(wincount=lambda df: df["str_repr"].map(win_counter).fillna(0).astype("int32"))
        .sort_values("strategy_idx")[["strategy_idx", "wincount"]]
    )
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("constructed summary DataFrame  vars=%s", vars_snippet)
    summary.to_csv("wincounts.csv", index=False)
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("wrote wincounts.csv  vars=%s", vars_snippet)
    log.info("Finished!  CSV written with final results.")
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("exiting main  vars=%s", vars_snippet)

# ──────────────────────────────────────────────────────────────────────────────
if __name__ == "__main__":
    # At this point, the handler + root logger are fully configured.
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("about to call main from __main__  vars=%s", vars_snippet)
    main()
    vars_snippet = short_vars(locals(), 100)                 
    log.debug("returned from main in __main__  vars=%s", vars_snippet)
# Out:
# 16:45:16 INFO  2510037422.py:89 | n_games_per_player = 10223, total tasks = 16683936
# 16:45:16 DEBUG 2510037422.py:322 | about to call main from __main__  vars={'__name__': '__main__', '__doc__': '\nRun the full Farkle strategy tournament with multiprocessing,…
# 16:45:16 DEBUG 2510037422.py:221 | reached main  vars={}
# 16:45:16 DEBUG 2510037422.py:168 | reached load_checkpoint  vars={}
# 16:45:16 DEBUG 2510037422.py:171 | load_checkpoint found no checkpoint file  vars={'vars_snippet': '{}'}
# 16:45:16 DEBUG 2510037422.py:224 | after load_checkpoint in main  vars={'vars_snippet': '{}', 'already_done': 0, 'win_counter': Counter()}
# 16:45:16 DEBUG 2510037422.py:234 | created log_queue in main  vars={'vars_snippet': "{'vars_snippet': '{}', 'already_done': 0, 'win_counter': Counter()}", 'already_don…
# 16:45:16 DEBUG 2510037422.py:238 | started listener process in main  vars={'vars_snippet': '{\'vars_snippet\': "{\'vars_snippet\': \'{}\', \'already_done\': 0, \'win_counter\…
# 16:45:16 DEBUG 2510037422.py:242 | recorded start_time in main  vars={'vars_snippet': '{\'vars_snippet\': \'{\\\'vars_snippet\\\': "{\\\'vars_snippet\\\': \\\'{}\\\', \\…
# 16:45:16 DEBUG 2510037422.py:245 | initialized done counter in main  vars={'vars_snippet': '{\'vars_snippet\': \'{\\\'vars_snippet\\\': \\\'{\\\\\\\'vars_snippet\\\\\\\': "{\…
# 16:45:16 DEBUG 2510037422.py:254 | entered Pool context in main  vars={'vars_snippet': '{\'vars_snippet\': \'{\\\'vars_snippet\\\': \\\'{\\\\\\\'vars_snippet\\\\\\\': \\\…
# 16:45:16 INFO  2510037422.py:255 | Pool started with 16 workers.
# 16:45:16 DEBUG 2510037422.py:257 | logged pool start info in main  vars={'vars_snippet': "{'vars_snippet': '{\\'vars_snippet\\': \\'{\\\\\\'vars_snippet\\\\\\': \\\\\\'{\\\…
# 16:45:16 DEBUG 2510037422.py:260 | created stream iterator in main  vars={'vars_snippet': '{\'vars_snippet\': "{\'vars_snippet\': \'{\\\\\'vars_snippet\\\\\': \\\\\'{\\\\\\\…
# 16:45:16 DEBUG 2510037422.py:125 | reached task_stream:  vars={'already_done': 0}
# 16:45:16 DEBUG 2510037422.py:135 | assigned task_stream variables vars={'already_done': 0, 'vars_snippet': "{'already_done': 0}", 'num_strats': 8160, 'tables_per_rep': 163…
# 16:45:16 DEBUG 2510037422.py:139 | entered loop in task_stream   vars={'already_done': 0, 'vars_snippet': '{\'already_done\': 0, \'vars_snippet\': "{\'already_done\': 0}"…

# %%
import threading, multiprocessing as mp
from collections import Counter
from pathlib import Path
import numpy as np
import pickle
import time
from __future__ import annotations

import logging
import logging.handlers
import multiprocessing as mp
import pickle
import sys
import time
from collections import Counter
from pathlib import Path
from typing import Tuple

import numpy as np

from farkle.simulation import generate_strategy_grid, _play_game
from farkle.stats import games_for_power

# ──────────────────────────────────────────────────────────────────────────────
# Globals
CHUNKSIZE       = 6
QUEUE_MAXSIZE   = 100
PROCESSES       = 16
REPORT_every    = 100_000
CHECKPOINT_FILE = Path("win_counter.chk")

# ──────────────────────────────────────────────────────────────────────────────
def producer(task_q, n_games_per_player, num_strats):
    """Thread #1: generate (seed, idxs) and put into task_q, up to QUEUE_MAXSIZE."""
    perm_rng = np.random.default_rng(999)
    seed_rng = np.random.default_rng(1234)

    for rep in range(n_games_per_player):
        perm = perm_rng.permutation(num_strats)
        # slice into 5‐player tables
        for j in range(0, num_strats, 5):
            if j + 5 > num_strats:
                break
            seed = int(seed_rng.integers(2**32))
            task_q.put((seed, tuple(int(x) for x in perm[j:j+5])))
    # signal end to workers
    for _ in range(PROCESSES):
        task_q.put(None)


def worker(task_q, result_q):
    """N processes: pull tasks 6 at a time, run games, push wins."""
    from farkle.simulation import _play_game  # worker imports
    while True:
        batch = []
        # gather up to CHUNKSIZE tasks
        for _ in range(CHUNKSIZE):
            task = task_q.get()
            if task is None:
                # re‐signal None so other workers see it
                task_q.put(None)
                break
            batch.append(task)

        if not batch:
            break

        # run each game in this batch
        for seed, idxs in batch:
            # reconstruct strategies list and play
            row = _play_game(seed, [strategies[i] for i in idxs], 10_000)
            win = str(row[f"{row['winner']}_strategy"])
            result_q.put(win)
    # when finished, let collector know
    result_q.put(None)


def collector(result_q, total_tasks):
    """Thread #2: pull wins, update counter, save checkpoints & CSV."""
    win_counter = Counter()
    done = 0
    active_workers = PROCESSES
    start = time.perf_counter()

    while active_workers:
        msg = result_q.get()
        if msg is None:
            active_workers -= 1
            continue
        win_counter[msg] += 1
        done += 1

        if done % REPORT_every == 0 or done == total_tasks:
            hrs = (time.perf_counter() - start)/3600
            print(f"[{done}/{total_tasks}] {hrs:.2f} h elapsed")
            with CHECKPOINT_FILE.open("wb") as f:
                pickle.dump({"done": done, "counter": dict(win_counter)}, f)

    # all workers done
    # final CSV
    import pandas as pd
    summary = (
      pd.DataFrame({"strategy_idx": range(num_strats),
                    "str_repr": [str(s) for s in strategies]})
        .assign(wincount=lambda df: df["str_repr"].map(win_counter).fillna(0).astype(int))
        .sort_values("strategy_idx")
    )
    summary.to_csv("wincounts.csv", index=False)
    print("Finished! CSV written.")

# ──────────────────────────────────────────────────────────────────────────────
if __name__ == "__main__":
    strategies, meta = generate_strategy_grid()
    num_strats      = len(strategies)
    n_games         = games_for_power(...)
    total_tasks     = num_strats * n_games // 5

    # Queues
    task_q   = mp.Queue(maxsize=QUEUE_MAXSIZE)
    result_q = mp.Queue()

    # Start producer thread
    prod_thread = threading.Thread(target=producer,
                                   args=(task_q, n_games, num_strats),
                                   daemon=True)
    prod_thread.start()

    # Start collector thread
    coll_thread = threading.Thread(target=collector,
                                   args=(result_q, total_tasks),
                                   daemon=True)
    coll_thread.start()

    # Spawn worker processes
    processes = []
    for _ in range(PROCESSES):
        p = mp.Process(target=worker, args=(task_q, result_q))
        p.start()
        processes.append(p)

    # Wait for everyone to finish
    for p in processes:
        p.join()
    coll_thread.join()
    print("All done.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 115
#     113 strategies, meta = generate_strategy_grid()
#     114 num_strats      = len(strategies)
# --> 115 n_games         = games_for_power(...)
#     116 total_tasks     = num_strats * n_games // 5
#     118 # Queues
#
# File S:\Libraries\OneDrive\Documents\Code Projects Parent Folder\Code Projects\Farkle Mk II\src\farkle\stats.py:23, in games_for_power(n_strategies, delta, base_p, alpha, power, method, pairwise)
#      21     alpha_star = alpha / k
#      22 elif method == "bh":
# ---> 23     h_m = sum(1/i for i in range(1, n_strategies+1))  # harmonic number
#      24     alpha_star = alpha / h_m
#      25 else:
#
# TypeError: unsupported operand type(s) for +: 'ellipsis' and 'int'

# %%
import threading
import multiprocessing as mp
from collections import Counter
from pathlib import Path
import pickle
import time

import numpy as np
import pandas as pd

from farkle.simulation import generate_strategy_grid
from farkle.stats import games_for_power

# ──────────────────────────────────────────────────────────────────────────────
# Globals
CHUNKSIZE       = 6
QUEUE_MAXSIZE   = 100
PROCESSES       = 16
REPORT_EVERY    = 100_000
CHECKPOINT_FILE = Path("win_counter.chk")


def producer(task_q: mp.Queue, n_games_per_player: int, num_strats: int) -> None:
    """Thread #1: generate (seed, idxs) and put into task_q, up to QUEUE_MAXSIZE."""
    perm_rng = np.random.default_rng(999)
    seed_rng = np.random.default_rng(1234)

    for rep in range(n_games_per_player):
        perm = perm_rng.permutation(num_strats)
        for j in range(0, num_strats, 5):
            if j + 5 > num_strats:
                break
            seed = int(seed_rng.integers(2**32))
            task_q.put((seed, tuple(int(x) for x in perm[j : j + 5])))
    # signal end to workers
    for _ in range(PROCESSES):
        task_q.put(None)


def worker(task_q: mp.Queue, result_q: mp.Queue) -> None:
    """Process: pull tasks CHUNKSIZE at a time, run games, push wins."""
    from farkle.simulation import _play_game  # worker import

    while True:
        batch = []
        for _ in range(CHUNKSIZE):
            task = task_q.get()
            if task is None:
                task_q.put(None)
                break
            batch.append(task)

        if not batch:
            break

        for seed, idxs in batch:
            row = _play_game(seed, [strategies[i] for i in idxs], 10_000)
            win = str(row[f"{row['winner']}_strategy"])
            result_q.put(win)
    # signal collector that this worker is done
    result_q.put(None)


def collector(result_q: mp.Queue, total_tasks: int) -> None:
    """Thread #2: pull wins, update counter, save checkpoints & CSV."""
    win_counter = Counter()
    done = 0
    active_workers = PROCESSES
    start = time.perf_counter()

    while active_workers:
        msg = result_q.get()
        if msg is None:
            active_workers -= 1
            continue
        win_counter[msg] += 1
        done += 1

        if done % REPORT_EVERY == 0 or done == total_tasks:
            hrs = (time.perf_counter() - start) / 3600
            print(f"[{done}/{total_tasks}] {hrs:.2f} h elapsed")
            with CHECKPOINT_FILE.open("wb") as f:
                pickle.dump({"done": done, "counter": dict(win_counter)}, f)

    # all workers done → final CSV
    summary = (
        pd.DataFrame({
            "strategy_idx": range(num_strats),
            "str_repr": [str(s) for s in strategies]
        })
        .assign(wincount=lambda df: df["str_repr"].map(win_counter).fillna(0).astype(int))
        .sort_values("strategy_idx")
    )
    summary.to_csv("wincounts.csv", index=False)
    print("Finished! CSV written.")


if __name__ == "__main__":
    # Prepare strategy grid and determine total tasks
    strategies, meta = generate_strategy_grid()
    num_strats = len(strategies)
    n_games_per_player = games_for_power(
        n_strategies=num_strats,
        delta=0.03, alpha=0.025, power=0.90,
        method="bh", pairwise=True,
    )
    total_tasks = num_strats * n_games_per_player // 5

    # Queues
    task_q = mp.Queue(maxsize=QUEUE_MAXSIZE)
    result_q = mp.Queue()

    # Start producer thread
    prod_thread = threading.Thread(
        target=producer,
        args=(task_q, n_games_per_player, num_strats),
        daemon=True
    )
    prod_thread.start()

    # Start collector thread
    coll_thread = threading.Thread(
        target=collector,
        args=(result_q, total_tasks),
        daemon=True
    )
    coll_thread.start()

    # Spawn worker processes
    processes = []
    for _ in range(PROCESSES):
        p = mp.Process(target=worker, args=(task_q, result_q))
        p.start()
        processes.append(p)

    # Wait for workers and collector to finish
    for p in processes:
        p.join()
    coll_thread.join()
    print("All done.")

# %%
#!/usr/bin/env python3
"""
Run the full Farkle strategy tournament with threading, multiprocessing,
producer–worker–collector pattern, queue-based logging, and resumable checkpoints.
"""
from __future__ import annotations

import logging
import logging.handlers
import threading
import multiprocessing as mp
import pickle
import sys
import time
from collections import Counter
from pathlib import Path
from typing import Tuple

import numpy as np
import pandas as pd

from farkle.simulation import generate_strategy_grid
from farkle.stats import games_for_power

# ──────────────────────────────────────────────────────────────────────────────
def short_vars(d: dict, max_len: int = 100) -> str:
    s = repr(d)
    return s if len(s) <= max_len else s[:max_len] + "…"

# ──────────────────────────────────────────────────────────────────────────────
# 0.--- Globals & tuning knobs
CHUNKSIZE       = 6           # tasks sent to each worker at a time
QUEUE_MAXSIZE   = 100         # max tasks buffered
PROCESSES       = 16
REPORT_EVERY    = 100_000     # progress print interval
CHECKPOINT_FILE = Path("win_counter.chk")

# ──────────────────────────────────────────────────────────────────────────────
# 1.--- Set up root logger and handler
DEBUG_FIRST_N = 10000   # change once; used by the filter below

class FirstNFilter(logging.Filter):
    """
    Let every unique call-site (file, lineno) speak `n` times, then silence it.
    """
    def __init__(self, n: int = DEBUG_FIRST_N):
        super().__init__()
        self.n = n
        self.seen: Counter[Tuple[str, int]] = Counter()

    def filter(self, record: logging.LogRecord) -> bool:
        key = (record.pathname, record.lineno)
        self.seen[key] += 1
        return self.seen[key] <= self.n

# configure the root logger
root = logging.getLogger()
root.setLevel(logging.DEBUG)
handler = logging.StreamHandler(sys.stdout)
handler.setFormatter(logging.Formatter(
    "%(asctime)s %(levelname)-5s %(filename)s:%(lineno)d | %(message)s",
    datefmt="%H:%M:%S"
))
handler.addFilter(FirstNFilter(DEBUG_FIRST_N))
root.handlers[:] = [handler]

# tournament logger
log = logging.getLogger("tournament")
log.setLevel(logging.DEBUG)

# ──────────────────────────────────────────────────────────────────────────────
# 2.--- Producer: enqueue tasks

def producer(task_q: mp.Queue, n_games_per_player: int, num_strats: int) -> None:
    vars_snippet = short_vars(locals(), 100)
    log.debug("reached producer start vars=%s", vars_snippet)
    perm_rng = np.random.default_rng(999)
    seed_rng = np.random.default_rng(1234)
    vars_snippet = short_vars(locals(), 100)
    log.debug("initialized producer RNGs vars=%s", vars_snippet)

    for rep in range(n_games_per_player):
        vars_snippet = short_vars(locals(), 100)
        log.debug("producer loop rep=%d vars=%s", rep, vars_snippet)
        perm = perm_rng.permutation(num_strats)
        for j in range(0, num_strats, 5):
            vars_snippet = short_vars(locals(), 100)
            # log.debug("producer inner loop j=%d vars=%s", j, vars_snippet)
            if j + 5 > num_strats:
                log.debug("producer breaking inner loop at j=%d", j)
                break
            seed = int(seed_rng.integers(2**32))
            task = (seed, tuple(int(x) for x in perm[j : j + 5]))
            task_q.put(task)
    vars_snippet = short_vars(locals(), 100)
    log.debug("producer signaling end vars=%s", vars_snippet)
    for _ in range(PROCESSES):
        task_q.put(None)
    log.debug("producer done")

# ──────────────────────────────────────────────────────────────────────────────
# 3.--- Worker processes: consume tasks

def worker(task_q: mp.Queue, result_q: mp.Queue) -> None:
    vars_snippet = short_vars(locals(), 100)
    log.debug("reached worker start vars=%s", vars_snippet)
    from farkle.simulation import _play_game  # delay import in worker

    while True:
        batch: list[tuple[int, tuple[int, ...]]] = []
        for _ in range(CHUNKSIZE):
            task = task_q.get()
            vars_snippet = short_vars(locals(), 100)
            log.debug("worker got task vars=%s", vars_snippet)
            if task is None:
                log.debug("worker received None sentinel")
                task_q.put(None)
                break
            batch.append(task)
        vars_snippet = short_vars(locals(), 100)
        log.debug("worker batch size=%d vars=%s", len(batch), vars_snippet)
        if not batch:
            log.debug("worker breaking - empty batch")
            break

        for seed, idxs in batch:
            vars_snippet = short_vars(locals(), 100)
            log.debug("worker playing game seed=%d idxs=%s vars=%s", seed, idxs, vars_snippet)
            row = _play_game(seed, [strategies[i] for i in idxs], 10_000)
            win = str(row[f"{row['winner']}_strategy"])
            result_q.put(win)
    vars_snippet = short_vars(locals(), 100)
    log.debug("worker sending None to collector vars=%s", vars_snippet)
    result_q.put(None)

# ──────────────────────────────────────────────────────────────────────────────
# 4.--- Collector: tally wins, checkpoints, and CSV

def collector(result_q: mp.Queue, total_tasks: int) -> None:
    vars_snippet = short_vars(locals(), 100)
    log.debug("reached collector start vars=%s", vars_snippet)
    win_counter = Counter()
    done = 0
    active_workers = PROCESSES
    start = time.perf_counter()

    while active_workers:
        msg = result_q.get()
        vars_snippet = short_vars(locals(), 100)
        log.debug("collector got msg vars=%s", vars_snippet)
        if msg is None:
            active_workers -= 1
            log.debug("collector worker done, active_workers=%d", active_workers)
            continue
        win_counter[msg] += 1
        done += 1

        if done % REPORT_EVERY == 0 or done == total_tasks:
            hrs = (time.perf_counter() - start) / 3600
            log.info("[%d/%d] %6.2f h elapsed", done, total_tasks, hrs)
            with CHECKPOINT_FILE.open("wb") as f:
                pickle.dump({"done": done, "counter": dict(win_counter)}, f)
            log.debug("collector saved checkpoint at done=%d", done)

    vars_snippet = short_vars(locals(), 100)
    log.debug("collector constructing final summary vars=%s", vars_snippet)
    summary = (
        pd.DataFrame({
            "strategy_idx": range(num_strats),
            "str_repr": [str(s) for s in strategies]
        })
        .assign(wincount=lambda df: df["str_repr"].map(win_counter).fillna(0).astype(int))
        .sort_values("strategy_idx")
    )
    log.debug("collector writing final CSV")
    summary.to_csv("wincounts.csv", index=False)
    log.info("Finished! CSV written.")

# ──────────────────────────────────────────────────────────────────────────────
# 5.--- Main entrypoint

if __name__ == "__main__":
    vars_snippet = short_vars(locals(), 100)
    log.debug("reached __main__ start vars=%s", vars_snippet)

    strategies, meta = generate_strategy_grid()
    num_strats = len(strategies)
    n_games_per_player = games_for_power(
        n_strategies=num_strats,
        delta=0.03, alpha=0.025, power=0.90,
        method="bh", pairwise=True,
    )
    total_tasks = num_strats * n_games_per_player // 5
    log.debug("computed grid vars=%s", short_vars(locals(), 100))

    task_q = mp.Queue(maxsize=QUEUE_MAXSIZE)
    result_q = mp.Queue()
    log.debug("queues created vars=%s", short_vars(locals(), 100))

    prod_thread = threading.Thread(
        target=producer,
        args=(task_q, n_games_per_player, num_strats),
        daemon=True
    )
    prod_thread.start()
    log.debug("producer thread started")

    coll_thread = threading.Thread(
        target=collector,
        args=(result_q, total_tasks),
        daemon=True
    )
    coll_thread.start()
    log.debug("collector thread started")

    processes: list[mp.Process] = []
    for _ in range(PROCESSES):
        p = mp.Process(target=worker, args=(task_q, result_q))
        p.start()
        processes.append(p)
    log.debug("worker processes started count=%d", len(processes))

    for p in processes:
        p.join()
    coll_thread.join()
    log.debug("all processes and collector joined")
    log.info("All done.")
# Out:
# 17:52:38 DEBUG 1541090730.py:184 | reached __main__ start vars={'__name__': '__main__', '__doc__': '\nRun the full Farkle strategy tournament with threading, multi…
# 17:52:38 DEBUG 1541090730.py:194 | computed grid vars={'__name__': '__main__', '__doc__': '\nRun the full Farkle strategy tournament with threading, multi…
# 17:52:38 DEBUG 1541090730.py:198 | queues created vars={'__name__': '__main__', '__doc__': '\nRun the full Farkle strategy tournament with threading, multi…
# 17:52:38 DEBUG 1541090730.py:76 | reached producer start vars={'task_q': <multiprocessing.queues.Queue object at 0x000001F77877E390>, 'n_games_per_player': 10223,…
# 17:52:38 DEBUG 1541090730.py:206 | producer thread started
# 17:52:38 DEBUG 1541090730.py:80 | initialized producer RNGs vars={'task_q': <multiprocessing.queues.Queue object at 0x000001F77877E390>, 'n_games_per_player': 10223,…
# 17:52:38 DEBUG 1541090730.py:84 | producer loop rep=0 vars={'task_q': <multiprocessing.queues.Queue object at 0x000001F77877E390>, 'n_games_per_player': 10223,…
# 17:52:38 DEBUG 1541090730.py:141 | reached collector start vars={'result_q': <multiprocessing.queues.Queue object at 0x000001F777097320>, 'total_tasks': 16683936}
# 17:52:38 DEBUG 1541090730.py:214 | collector thread started
# 17:52:39 DEBUG 1541090730.py:221 | worker processes started count=16

# %%
#!/usr/bin/env python3
from __future__ import annotations
import logging, multiprocessing as mp, threading, pickle, sys, time
from collections import Counter
from pathlib import Path
from typing import List, Tuple
import numpy as np, pandas as pd
from farkle.simulation import generate_strategy_grid, _play_game
from farkle.stats import games_for_power

CHUNKSIZE = 200
FLUSH_EVERY = 1000
PROCESSES = 16
QUEUE_MAXSIZE = 50_000
REPORT_EVERY = 100_000
CHECKPOINT_FILE = Path("win_counter.chk")
DEBUG_FIRST_N = 10000

class FirstNFilter(logging.Filter):
    def __init__(self, n: int = DEBUG_FIRST_N):
        super().__init__()
        self.n = n
        self.seen: Counter[Tuple[str, int]] = Counter()
    def filter(self, record: logging.LogRecord) -> bool:
        key = (record.pathname, record.lineno)
        self.seen[key] += 1
        return self.seen[key] <= self.n

root = logging.getLogger()
root.setLevel(logging.DEBUG)
handler = logging.StreamHandler(sys.stdout)
handler.setFormatter(logging.Formatter(
    "%(asctime)s %(levelname)-5s | %(filename)s:%(lineno)d | %(message)s",
    datefmt="%H:%M:%S"
))
handler.addFilter(FirstNFilter())
root.handlers[:] = [handler]
log = logging.getLogger("tournament")
log.setLevel(logging.DEBUG)

def producer(task_q: mp.Queue, n_games_per_player: int, num_strats: int) -> None:
    log.debug("producer start n_games_per_player=%d num_strats=%d", n_games_per_player, num_strats)
    perm_rng = np.random.default_rng(999)
    seed_rng = np.random.default_rng(1234)
    log.debug("producer RNGs initialized")
    for rep in range(n_games_per_player):
        # log.debug("producer iteration rep=%d", rep)
        perm = perm_rng.permutation(num_strats)
        for j in range(0, num_strats, 5):
            # log.debug("producer inner j=%d", j)
            if j + 5 > num_strats:
                log.debug("producer breaking inner loop at j=%d", j)
                break
            seed = int(seed_rng.integers(2**32))
            task = (seed, tuple(int(x) for x in perm[j:j+5]))
            task_q.put(task)
            # log.debug("producer enqueued task %s", task)
    for _ in range(PROCESSES):
        task_q.put(None)
        log.debug("producer sent sentinel None")
    log.debug("producer done")

def worker(strat_list: List, task_q: mp.Queue, result_q: mp.Queue) -> None:
    log.debug("worker start")
    global strategies
    strategies = strat_list
    local_counter: Counter[str] = Counter()
    processed = 0
    while True:
        batch: List[Tuple[int, Tuple[int, ...]]] = []
        sentinel = False
        for _ in range(CHUNKSIZE):
            task = task_q.get()
            log.debug("worker got task %s", task)
            if task is None:
                log.debug("worker received sentinel None")
                sentinel = True
                break
            batch.append(task)
        log.debug("worker batch size=%d", len(batch))
        if not batch and sentinel:
            log.debug("worker exiting: empty batch and sentinel")
            break
        for seed, idxs in batch:
            row = _play_game(seed, [strategies[i] for i in idxs], 10_000)
            winner_key = str(row[f"{row['winner']}_strategy"])
            local_counter[winner_key] += 1
            processed += 1
            log.debug("worker processed game %d winner=%s", processed, winner_key)
            if processed % FLUSH_EVERY == 0:
                result_q.put(local_counter)
                log.debug("worker flushed local_counter at processed=%d", processed)
                local_counter = Counter()
        if sentinel:
            log.debug("worker exiting after sentinel")
            break
    if local_counter:
        result_q.put(local_counter)
        log.debug("worker final flush local_counter")
    result_q.put(None)
    log.debug("worker sent final sentinel None")

def collector(result_q: mp.Queue) -> None:
    log.debug("collector start")
    win_counter: Counter[str] = Counter()
    done_batches = 0
    active_workers = PROCESSES
    start = time.perf_counter()
    while active_workers:
        msg = result_q.get()
        log.debug("collector got msg %s", msg)
        if msg is None:
            active_workers -= 1
            log.debug("collector worker done, active_workers=%d", active_workers)
            continue
        win_counter.update(msg)
        done_batches += 1
        log.debug("collector updated win_counter with batch, done_batches=%d", done_batches)
        if done_batches % REPORT_EVERY == 0 or active_workers == 0:
            hrs = (time.perf_counter() - start) / 3600
            log.info("[batch %d] %.2f h elapsed", done_batches, hrs)
            with CHECKPOINT_FILE.open("wb") as f:
                pickle.dump({"done": done_batches, "counter": dict(win_counter)}, f)
            log.debug("collector saved checkpoint at done_batches=%d", done_batches)
    df = pd.DataFrame({
        "strategy_idx": range(len(strategies)),
        "str_repr": [str(s) for s in strategies],
    })
    df["wincount"] = df["str_repr"].map(win_counter).fillna(0).astype(int)
    df.to_csv("wincounts.csv", index=False)
    log.info("collector CSV written")

if __name__ == "__main__":
    log.debug("main start")
    strategies, _ = generate_strategy_grid()
    num_strats = len(strategies)
    n_games_per_player = games_for_power(
        n_strategies=num_strats,
        delta=0.03,
        alpha=0.025,
        power=0.90,
        method="bh",
        pairwise=True,
    )
    total_tasks = num_strats * n_games_per_player // 5
    log.info("Grid: %d strategies, %d games/strat ⇒ %d tasks.", num_strats, n_games_per_player, total_tasks)
    ctx = mp.get_context("spawn")
    task_q = ctx.Queue(maxsize=QUEUE_MAXSIZE)
    result_q = ctx.Queue(maxsize=QUEUE_MAXSIZE)
    threading.Thread(target=producer, args=(task_q, n_games_per_player, num_strats), daemon=True).start()
    log.debug("producer thread started")
    threading.Thread(target=collector, args=(result_q,), daemon=True).start()
    log.debug("collector thread started")
    processes = [ctx.Process(target=worker, args=(strategies, task_q, result_q)) for _ in range(PROCESSES)]
    for p in processes:
        p.start()
        log.debug("worker process started pid=%s", p.pid)
    for p in processes:
        p.join()
        log.debug("worker process joined pid=%s", p.pid)
    log.info("All workers joined – tournament complete.")
# Out:
# 18:13:21 DEBUG | 4021196756.py:134 | main start
# 18:13:21 INFO  | 4021196756.py:146 | Grid: 8160 strategies, 10223 games/strat ⇒ 16683936 tasks.
# 18:13:21 DEBUG | 4021196756.py:42 | producer start n_games_per_player=10223 num_strats=8160
# 18:13:21 DEBUG | 4021196756.py:151 | producer thread started
# 18:13:21 DEBUG | 4021196756.py:45 | producer RNGs initialized
# 18:13:21 DEBUG | 4021196756.py:104 | collector start
# 18:13:21 DEBUG | 4021196756.py:153 | collector thread started

# %%
#!/usr/bin/env python3
from __future__ import annotations
import logging, multiprocessing as mp, threading, pickle, sys, time
from collections import Counter
from pathlib import Path
from typing import List, Tuple
import numpy as np, pandas as pd
from farkle.simulation import generate_strategy_grid, _play_game
from farkle.stats import games_for_power

CHUNKSIZE = 200
FLUSH_EVERY = 1000
PROCESSES = 16
QUEUE_MAXSIZE = 50_000
REPORT_EVERY = 100_000

# Robust project-root detection (works in scripts, modules, notebooks)
def find_project_root() -> Path:
    try:
        start = Path(__file__).resolve()
    except NameError:
        start = Path.cwd()
    for p in (start, *start.parents):
        if (p / "pyproject.toml").is_file():  # package folder marks root
            return p
    return Path.cwd()

PROJECT_ROOT = find_project_root()
CHECKPOINT_DIR = PROJECT_ROOT / "data" / "checkpoints"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
CHECKPOINT_FILE = CHECKPOINT_DIR / "win_counter.chk"

DEBUG_FIRST_N = 10000
class FirstNFilter(logging.Filter):
    def __init__(self, n: int = DEBUG_FIRST_N):
        super().__init__()
        self.n = n
        self.seen: Counter[Tuple[str, int]] = Counter()
    def filter(self, record: logging.LogRecord) -> bool:
        key = (record.pathname, record.lineno)
        self.seen[key] += 1
        return self.seen[key] <= self.n

root = logging.getLogger()
root.setLevel(logging.DEBUG)
handler = logging.StreamHandler(sys.stdout)
handler.setFormatter(logging.Formatter(
    "%(asctime)s %(levelname)-5s | %(filename)s:%(lineno)d | %(message)s",
    datefmt="%H:%M:%S"
))
handler.addFilter(FirstNFilter())
root.handlers[:] = [handler]
log = logging.getLogger("tournament")
log.setLevel(logging.DEBUG)

def producer(task_q: mp.Queue, n_games_per_player: int, num_strats: int) -> None:
    log.debug("producer start n_games_per_player=%d num_strats=%d", n_games_per_player, num_strats)
    perm_rng = np.random.default_rng(999)
    seed_rng = np.random.default_rng(1234)
    log.debug("producer RNGs initialized")
    for rep in range(n_games_per_player):
        # log.debug("producer iteration rep=%d", rep)
        perm = perm_rng.permutation(num_strats)
        for j in range(0, num_strats, 5):
            # log.debug("producer inner j=%d", j)
            if j + 5 > num_strats:
                log.debug("producer breaking inner loop at j=%d", j)
                break
            seed = int(seed_rng.integers(2**32))
            task = (seed, tuple(int(x) for x in perm[j:j+5]))
            task_q.put(task)
            # log.debug("producer enqueued task %s", task)
    log.debug("Finished 1st producer loop")
    for _ in range(PROCESSES):
        task_q.put(None)
        log.debug("producer sent sentinel None")
    log.debug("producer done")

def worker(strat_list: List, task_q: mp.Queue, result_q: mp.Queue) -> None:
    log.debug("worker start")
    global strategies
    strategies = strat_list
    local_counter: Counter[str] = Counter()
    processed = 0
    while True:
        batch: List[Tuple[int, Tuple[int, ...]]] = []
        sentinel = False
        for _ in range(CHUNKSIZE):
            task = task_q.get()
            log.debug("worker got task %s", task)
            if task is None:
                log.debug("worker received sentinel None")
                sentinel = True
                break
            batch.append(task)
        log.debug("worker batch size=%d", len(batch))
        if not batch and sentinel:
            log.debug("worker exiting: empty batch and sentinel")
            break
        for seed, idxs in batch:
            row = _play_game(seed, [strategies[i] for i in idxs], 10_000)
            winner_key = str(row[f"{row['winner']}_strategy"])
            local_counter[winner_key] += 1
            processed += 1
            log.debug("worker processed game %d winner=%s", processed, winner_key)
            if processed % FLUSH_EVERY == 0:
                result_q.put(local_counter)
                log.debug("worker flushed local_counter at processed=%d", processed)
                local_counter = Counter()
        if sentinel:
            log.debug("worker exiting after sentinel")
            break
    if local_counter:
        result_q.put(local_counter)
        log.debug("worker final flush local_counter")
    result_q.put(None)
    log.debug("worker sent final sentinel None")

def collector(result_q: mp.Queue) -> None:
    log.debug("collector start")
    win_counter: Counter[str] = Counter()
    done_batches = 0
    active_workers = PROCESSES
    start = time.perf_counter()
    while active_workers:
        msg = result_q.get()
        log.debug("collector got msg %s", msg)
        if msg is None:
            active_workers -= 1
            log.debug("collector worker done, active_workers=%d", active_workers)
            continue
        win_counter.update(msg)
        done_batches += 1
        log.debug("collector updated win_counter with batch, done_batches=%d", done_batches)
        if done_batches % REPORT_EVERY == 0 or active_workers == 0:
            hrs = (time.perf_counter() - start) / 3600
            log.info("[batch %d] %.2f h elapsed", done_batches, hrs)
            with CHECKPOINT_FILE.open("wb") as f:
                pickle.dump({"done": done_batches, "counter": dict(win_counter)}, f)
            log.debug("collector saved checkpoint at done_batches=%d", done_batches)
    df = pd.DataFrame({
        "strategy_idx": range(len(strategies)),
        "str_repr": [str(s) for s in strategies],
    })
    df["wincount"] = df["str_repr"].map(win_counter).fillna(0).astype(int)
    df.to_csv("wincounts.csv", index=False)
    log.info("collector CSV written")

def main():
    log.debug("main start")
    strategies, _ = generate_strategy_grid()
    num_strats = len(strategies)
    n_games_per_player = games_for_power(
        n_strategies=num_strats,
        delta=0.03,
        alpha=0.025,
        power=0.90,
        method="bh",
        pairwise=True,
    )
    total_tasks = num_strats * n_games_per_player // 5
    log.info("Grid: %d strategies, %d games/strat ⇒ %d tasks.", num_strats, n_games_per_player, total_tasks)
    ctx = mp.get_context("spawn")
    task_q = ctx.Queue(maxsize=QUEUE_MAXSIZE)
    result_q = ctx.Queue(maxsize=QUEUE_MAXSIZE)
    threading.Thread(target=producer, args=(task_q, n_games_per_player, num_strats), daemon=True).start()
    log.debug("producer thread started")
    threading.Thread(target=collector, args=(result_q,), daemon=True).start()
    log.debug("collector thread started")
    processes = [ctx.Process(target=worker, args=(strategies, task_q, result_q)) for _ in range(PROCESSES)]
    for p in processes:
        p.start()
        log.debug("worker process started pid=%s", p.pid)
    for p in processes:
        p.join()
        log.debug("worker process joined pid=%s", p.pid)
    log.info("All workers joined – tournament complete.")

if __name__ == "__main__":
    main()
# Out:
# 18:43:59 DEBUG | 2990622369.py:150 | main start
# 18:43:59 INFO  | 2990622369.py:162 | Grid: 8160 strategies, 10223 games/strat ⇒ 16683936 tasks.
# 18:43:59 DEBUG | 2990622369.py:57 | producer start n_games_per_player=10223 num_strats=8160
# 18:43:59 DEBUG | 2990622369.py:167 | producer thread started
# 18:43:59 DEBUG | 2990622369.py:60 | producer RNGs initialized
# 18:43:59 DEBUG | 2990622369.py:120 | collector start
# 18:43:59 DEBUG | 2990622369.py:169 | collector thread started
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=0
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=5
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=10
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=15
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=20
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=25
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=30
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=35
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=40
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=45
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=50
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=55
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=60
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=65
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=70
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=75
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=80
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=85
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=90
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=95
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=100
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=105
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=110
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=115
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=120
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=125
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=130
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=135
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=140
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=145
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=150
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=155
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=160
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=165
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=170
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=175
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=180
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=185
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=190
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=195
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=200
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=205
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=210
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=215
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=220
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=225
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=230
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=235
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=240
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=245
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=250
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=255
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=260
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=265
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=270
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=275
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=280
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=285
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=290
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=295
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=300
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=305
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=310
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=315
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=320
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=325
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=330
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=335
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=340
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=345
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=350
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=355
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=360
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=365
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=370
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=375
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=380
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=385
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=390
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=395
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=400
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=405
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=410
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=415
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=420
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=425
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=430
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=435
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=440
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=445
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=450
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=455
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=460
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=465
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=470
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=475
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=480
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=485
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=490
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=495
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=500
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=505
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=510
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=515
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=520
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=525
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=530
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=535
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=540
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=545
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=550
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=555
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=560
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=565
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=570
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=575
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=580
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=585
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=590
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=595
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=600
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=605
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=610
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=615
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=620
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=625
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=630
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=635
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=640
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=645
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=650
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=655
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=660
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=665
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=670
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=675
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=680
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=685
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=690
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=695
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=700
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=705
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=710
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=715
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=720
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=725
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=730
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=735
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=740
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=745
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=750
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=755
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=760
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=765
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=770
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=775
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=780
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=785
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=790
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=795
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=800
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=805
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=810
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=815
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=820
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=825
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=830
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=835
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=840
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=845
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=850
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=855
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=860
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=865
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=870
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=875
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=880
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=885
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=890
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=895
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=900
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=905
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=910
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=915
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=920
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=925
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=930
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=935
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=940
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=945
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=950
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=955
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=960
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=965
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=970
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=975
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=980
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=985
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=990
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=995
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1000
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1005
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1010
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1015
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1020
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1025
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1030
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1035
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1040
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1045
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1050
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1055
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1060
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1065
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1070
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1075
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1080
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1085
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1090
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1095
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1100
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1105
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1110
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1115
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1120
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1125
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1130
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1135
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1140
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1145
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1150
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1155
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1160
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1165
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1170
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1175
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1180
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1185
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1190
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1195
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1200
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1205
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1210
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1215
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1220
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1225
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1230
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1235
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1240
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1245
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1250
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1255
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1260
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1265
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1270
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1275
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1280
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1285
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1290
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1295
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1300
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1305
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1310
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1315
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1320
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1325
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1330
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1335
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1340
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1345
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1350
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1355
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1360
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1365
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1370
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1375
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1380
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1385
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1390
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1395
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1400
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1405
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1410
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1415
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1420
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1425
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1430
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1435
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1440
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1445
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1450
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1455
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1460
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1465
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1470
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1475
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1480
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1485
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1490
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1495
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1500
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1505
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1510
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1515
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1520
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1525
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1530
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1535
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1540
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1545
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1550
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1555
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1560
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1565
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1570
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1575
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1580
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1585
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1590
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1595
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1600
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1605
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1610
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1615
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1620
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1625
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1630
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1635
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1640
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1645
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1650
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1655
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1660
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1665
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1670
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1675
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1680
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1685
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1690
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1695
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1700
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1705
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1710
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1715
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1720
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1725
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1730
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1735
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1740
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1745
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1750
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1755
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1760
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1765
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1770
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1775
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1780
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1785
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1790
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1795
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1800
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1805
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1810
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1815
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1820
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1825
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1830
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1835
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1840
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1845
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1850
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1855
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1860
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1865
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1870
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1875
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1880
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1885
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1890
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1895
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1900
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1905
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1910
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1915
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1920
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1925
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1930
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1935
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1940
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1945
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1950
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1955
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1960
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1965
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1970
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1975
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1980
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1985
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1990
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=1995
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2000
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2005
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2010
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2015
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2020
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2025
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2030
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2035
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2040
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2045
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2050
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2055
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2060
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2065
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2070
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2075
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2080
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2085
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2090
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2095
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2100
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2105
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2110
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2115
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2120
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2125
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2130
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2135
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2140
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2145
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2150
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2155
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2160
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2165
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2170
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2175
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2180
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2185
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2190
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2195
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2200
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2205
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2210
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2215
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2220
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2225
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2230
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2235
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2240
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2245
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2250
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2255
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2260
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2265
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2270
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2275
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2280
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2285
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2290
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2295
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2300
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2305
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2310
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2315
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2320
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2325
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2330
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2335
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2340
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2345
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2350
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2355
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2360
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2365
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2370
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2375
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2380
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2385
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2390
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2395
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2400
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2405
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2410
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2415
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2420
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2425
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2430
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2435
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2440
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2445
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2450
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2455
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2460
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2465
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2470
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2475
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2480
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2485
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2490
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2495
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2500
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2505
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2510
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2515
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2520
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2525
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2530
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2535
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2540
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2545
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2550
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2555
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2560
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2565
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2570
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2575
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2580
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2585
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2590
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2595
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2600
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2605
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2610
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2615
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2620
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2625
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2630
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2635
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2640
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2645
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2650
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2655
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2660
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2665
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2670
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2675
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2680
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2685
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2690
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2695
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2700
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2705
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2710
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2715
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2720
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2725
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2730
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2735
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2740
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2745
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2750
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2755
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2760
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2765
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2770
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2775
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2780
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2785
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2790
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2795
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2800
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2805
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2810
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2815
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2820
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2825
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2830
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2835
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2840
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2845
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2850
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2855
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2860
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2865
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2870
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2875
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2880
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2885
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2890
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2895
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2900
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2905
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2910
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2915
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2920
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2925
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2930
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2935
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2940
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2945
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2950
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2955
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2960
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2965
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2970
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2975
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2980
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2985
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2990
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=2995
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3000
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3005
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3010
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3015
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3020
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3025
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3030
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3035
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3040
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3045
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3050
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3055
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3060
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3065
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3070
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3075
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3080
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3085
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3090
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3095
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3100
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3105
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3110
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3115
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3120
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3125
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3130
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3135
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3140
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3145
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3150
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3155
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3160
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3165
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3170
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3175
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3180
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3185
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3190
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3195
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3200
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3205
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3210
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3215
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3220
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3225
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3230
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3235
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3240
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3245
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3250
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3255
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3260
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3265
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3270
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3275
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3280
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3285
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3290
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3295
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3300
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3305
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3310
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3315
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3320
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3325
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3330
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3335
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3340
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3345
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3350
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3355
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3360
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3365
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3370
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3375
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3380
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3385
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3390
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3395
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3400
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3405
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3410
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3415
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3420
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3425
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3430
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3435
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3440
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3445
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3450
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3455
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3460
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3465
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3470
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3475
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3480
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3485
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3490
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3495
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3500
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3505
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3510
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3515
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3520
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3525
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3530
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3535
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3540
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3545
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3550
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3555
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3560
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3565
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3570
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3575
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3580
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3585
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3590
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3595
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3600
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3605
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3610
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3615
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3620
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3625
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3630
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3635
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3640
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3645
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3650
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3655
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3660
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3665
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3670
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3675
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3680
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3685
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3690
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3695
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3700
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3705
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3710
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3715
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3720
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3725
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3730
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3735
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3740
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3745
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3750
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3755
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3760
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3765
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3770
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3775
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3780
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3785
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3790
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3795
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3800
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3805
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3810
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3815
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3820
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3825
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3830
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3835
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3840
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3845
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3850
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3855
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3860
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3865
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3870
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3875
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3880
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3885
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3890
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3895
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3900
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3905
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3910
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3915
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3920
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3925
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3930
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3935
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3940
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3945
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3950
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3955
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3960
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3965
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3970
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3975
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3980
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3985
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3990
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=3995
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4000
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4005
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4010
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4015
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4020
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4025
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4030
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4035
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4040
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4045
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4050
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4055
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4060
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4065
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4070
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4075
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4080
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4085
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4090
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4095
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4100
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4105
# 18:43:59 DEBUG | 2990622369.py:65 | producer inner j=4110
# ...
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7805
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7810
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7815
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7820
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7825
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7830
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7835
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7840
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7845
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7850
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7855
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7860
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7865
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7870
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7875
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7880
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7885
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7890
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7895
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7900
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7905
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7910
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7915
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7920
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7925
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7930
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7935
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7940
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7945
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7950
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7955
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7960
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7965
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7970
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7975
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7980
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7985
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7990
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=7995
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8000
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8005
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8010
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8015
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8020
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8025
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8030
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8035
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8040
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8045
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8050
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8055
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8060
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8065
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8070
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8075
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8080
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8085
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8090
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8095
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8100
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8105
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8110
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8115
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8120
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8125
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8130
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8135
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8140
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8145
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8150
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=8155
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=0
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=5
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=10
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=15
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=20
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=25
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=30
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=35
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=40
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=45
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=50
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=55
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=60
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=65
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=70
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=75
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=80
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=85
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=90
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=95
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=100
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=105
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=110
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=115
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=120
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=125
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=130
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=135
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=140
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=145
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=150
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=155
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=160
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=165
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=170
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=175
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=180
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=185
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=190
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=195
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=200
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=205
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=210
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=215
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=220
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=225
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=230
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=235
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=240
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=245
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=250
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=255
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=260
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=265
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=270
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=275
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=280
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=285
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=290
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=295
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=300
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=305
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=310
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=315
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=320
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=325
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=330
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=335
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=340
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=345
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=350
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=355
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=360
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=365
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=370
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=375
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=380
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=385
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=390
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=395
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=400
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=405
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=410
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=415
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=420
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=425
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=430
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=435
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=440
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=445
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=450
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=455
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=460
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=465
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=470
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=475
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=480
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=485
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=490
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=495
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=500
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=505
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=510
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=515
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=520
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=525
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=530
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=535
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=540
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=545
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=550
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=555
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=560
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=565
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=570
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=575
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=580
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=585
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=590
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=595
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=600
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=605
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=610
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=615
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=620
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=625
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=630
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=635
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=640
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=645
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=650
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=655
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=660
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=665
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=670
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=675
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=680
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=685
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=690
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=695
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=700
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=705
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=710
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=715
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=720
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=725
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=730
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=735
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=740
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=745
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=750
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=755
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=760
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=765
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=770
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=775
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=780
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=785
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=790
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=795
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=800
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=805
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=810
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=815
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=820
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=825
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=830
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=835
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=840
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=845
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=850
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=855
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=860
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=865
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=870
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=875
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=880
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=885
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=890
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=895
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=900
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=905
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=910
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=915
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=920
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=925
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=930
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=935
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=940
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=945
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=950
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=955
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=960
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=965
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=970
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=975
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=980
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=985
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=990
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=995
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1000
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1005
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1010
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1015
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1020
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1025
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1030
# 18:44:05 DEBUG | 2990622369.py:65 | producer inner j=1035
