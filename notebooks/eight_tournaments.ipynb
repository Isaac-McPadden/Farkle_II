# %%
GLOBAL_SEED = 42

# -----------------------------------------------------------------
# You almost never change these:
from pathlib import Path
BASE_OUT = Path("data/results")
JOBS     = None            # None → use all logical cores
BASE_OUT.mkdir(parents=True, exist_ok=True)
# Power-analysis helpers  ───────────────────────────────────────────
from math import ceil, log
from scipy.stats import norm

def harmonic_number(m: int) -> float:
    """Approximate H_m for m ≥ 1 (no mpmath needed)."""
    if m < 50_000:
        return sum(1/i for i in range(1, m+1))
    # Euler–Mascheroni expansion (error < 1e-7 for m ≥ 50 000)
    from math import euler_gamma
    return log(m) + euler_gamma + 1/(2*m) - 1/(12*m**2)

def games_for_power(m: int,
                    n_players: int,
                    delta: float = 0.03,
                    power: float = 0.80,
                    q_fdr: float = 0.05) -> int:
    """
    Returns required *games per strategy* under BH-controlled FDR.
    One game per strategy per shuffle ⇒ result == num. shuffles.
    """
    # BH per-test alpha*  ≈  q / H_m   (Benjamini & Hochberg, 1995)
    alpha_star = q_fdr / harmonic_number(m)
    z_alpha = norm.isf(alpha_star / 2)          # two-sided
    z_beta  = norm.isf(1 - power)
    
    p0 = 1 / n_players if n_players > 2 else 0.5   # null win rate
    p1 = p0 + delta
    var  = p0*(1-p0) + p1*(1-p1)
    
    n = ((z_alpha + z_beta)**2 * var) / (delta**2)
    return ceil(n)

# CONFIG N-player run ───────────────────────────────────────────────
GRID        = 8_160         # strategies
N_PLAYERS   = 3
DELTA       = 0.03
POWER       = 0.80
Q_FDR       = 0.05
# ------------------------------------------------------------------

NUM_SHUFFLES        = games_for_power(GRID, N_PLAYERS,
                                      delta=DELTA,
                                      power=POWER,
                                      q_fdr=Q_FDR)
GAMES_PER_SHUFFLE   = GRID // N_PLAYERS
TOTAL_GAMES         = NUM_SHUFFLES * GAMES_PER_SHUFFLE

print(f"Benjamini–Hochberg FDR = {Q_FDR}")
print(f"  Strategies            : {GRID:,}")
print(f"  Players per table     : {N_PLAYERS}")
print(f"  Δ (detectable lift)   : {DELTA:.0%}")
print(f"  Power (1-β)           : {POWER:.0%}")
print(f"  Per-test α*           : {Q_FDR/harmonic_number(GRID):.4f}")
print(f"  Num. shuffles         : {NUM_SHUFFLES:,}")
print(f"  Games per shuffle     : {GAMES_PER_SHUFFLE}")
print(f"  Total games           : {TOTAL_GAMES:,}")

# %%time
import importlib, multiprocessing as mp
import farkle.run_tournament as rt

# ── patch driver-side constants ───────────────────────────────────
rt = importlib.reload(rt)                 # fresh copy each run
rt.N_PLAYERS         = N_PLAYERS
rt.GAMES_PER_SHUFFLE = GAMES_PER_SHUFFLE  # GRID // N_PLAYERS
rt.NUM_SHUFFLES      = NUM_SHUFFLES       # ← NEW: power-target cap

# ── output paths etc. (assumes BASE_OUT / GLOBAL_SEED / JOBS exist) ─
out_dir = BASE_OUT / f"{N_PLAYERS}_players"
out_dir.mkdir(exist_ok=True)
chkpt   = out_dir / "checkpoint.pkl"
row_dir = out_dir / "rows"

# ── launch ────────────────────────────────────────────────────────
mp.set_start_method("spawn", force=True)  # Windows & Jupyter safe
rt.run_tournament(
    global_seed         = GLOBAL_SEED,
    checkpoint_path     = chkpt,
    n_jobs              = JOBS,
    collect_metrics     = True,
    row_output_directory= row_dir,
)
print(f"✔ finished {N_PLAYERS}-player run →", out_dir)

# %%
import pickle, pandas as pd, seaborn as sns, matplotlib.pyplot as plt

# aggregated win / score sums
with open(chkpt, "rb") as fh:
    summary = pickle.load(fh)
summary_df = pd.DataFrame(summary)    # one row per strategy
summary_df.sort_values("wins", ascending=False)

# full per-game rows (optional; can be large)
rows = pd.read_parquet(row_dir)       # auto-globs *.parquet
rows.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18480\2625201221.py in ?()
#       3 # aggregated win / score sums
#       4 with open(chkpt, "rb") as fh:
#       5     summary = pickle.load(fh)
#       6 summary_df = pd.DataFrame(summary)    # one row per strategy
# ----> 7 summary_df.sort_values("wins", ascending=False)
#       8
#       9 # full per-game rows (optional; can be large)
#      10 rows = pd.read_parquet(row_dir)       # auto-globs *.parquet
#
# s:\Libraries\OneDrive\Documents\Code Projects Parent Folder\Code Projects\Farkle Mk II\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7192             )
#    7193         elif len(by):
#    7194             # len(by) == 1
#    7195
# -> 7196             k = self._get_label_or_level_values(by[0], axis=axis)
#    7197
#    7198             # need to rewrap column in Series to apply key function
#    7199             if key is not None:
#
# s:\Libraries\OneDrive\Documents\Code Projects Parent Folder\Code Projects\Farkle Mk II\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'wins'

# %%
# -----------------------------------------------------------------
# GLOBAL constants you rarely change
GLOBAL_SEED  = 42
from pathlib import Path
BASE_OUT     = Path("data/results"); BASE_OUT.mkdir(parents=True, exist_ok=True)
JOBS         = None                  # None → use all logical cores
# -----------------------------------------------------------------

# ── Power-analysis helpers ─────────────────────────────────────────
from math import ceil
from scipy.stats import norm

def shuffles_required(n_players: int,
                      delta: float = 0.03,
                      power: float = 0.90,
                      q_fdr: float = 0.02,
                      two_sided: bool = True) -> int:
    """
    Minimum *shuffles* (games/strategy) so that a two-proportion z-test
    has `power` to detect an absolute lift `delta`, while the Benjamini–
    Hochberg procedure controls FDR at `q_fdr`.
    
    One shuffle gives exactly one observation per strategy, so
    shuffles == observations/strategy.
    """
    p0      = 1 / n_players            # null win probability
    z_alpha = norm.isf((q_fdr/2) if two_sided else q_fdr)
    z_beta  = norm.isf(power)          # power = Φ(z_beta)
    
    var = p0*(1-p0) + (p0+delta)*(1-p0-delta)
    n   = ((z_alpha + z_beta)**2 * var) / (delta**2)
    return ceil(n)

# ── CONFIG: choose the table size you’re about to run ──────────────
GRID        = 8_160            # total strategies (constant)
N_PLAYERS   = 2                # ← change 2,3,4,… per run
DELTA       = 0.03
POWER       = 0.90
Q_FDR       = 0.02
# ------------------------------------------------------------------

NUM_SHUFFLES        = shuffles_required(N_PLAYERS,
                                        delta  = DELTA,
                                        power  = POWER,
                                        q_fdr  = Q_FDR)
GAMES_PER_SHUFFLE   = GRID // N_PLAYERS
TOTAL_GAMES         = NUM_SHUFFLES * GAMES_PER_SHUFFLE

print(f"Benjamini–Hochberg FDR (two-sided) : Q = {Q_FDR}")
print(f"Players per table                  : {N_PLAYERS}")
print(f"Detectable lift Δ                  : {DELTA:.0%}")
print(f"Power (1-β)                        : {POWER:.0%}")
print(f"Critical z_α                       : {norm.isf(Q_FDR/2):.3f}")
print(f"Shuffles (obs/strategy)            : {NUM_SHUFFLES:,}")
print(f"Games per shuffle                  : {GAMES_PER_SHUFFLE}")
print(f"Total games this run               : {TOTAL_GAMES:,}")

# -----------------------------------------------------------------
#   Launch the tournament in next cell
# -----------------------------------------------------------------
# Out:
# Benjamini–Hochberg FDR (two-sided) : Q = 0.02
# Players per table                  : 2
# Detectable lift Δ                  : 3%
# Power (1-β)                        : 90%
# Critical z_α                       : 2.326
# Shuffles (obs/strategy)            : 606
# Games per shuffle                  : 4080
# Total games this run               : 2,472,480

# %%
# %%time
import importlib, multiprocessing as mp
import farkle.run_tournament as rt

rt = importlib.reload(rt)                   # fresh copy each run
rt.N_PLAYERS         = N_PLAYERS
rt.GAMES_PER_SHUFFLE = GAMES_PER_SHUFFLE
rt.NUM_SHUFFLES      = NUM_SHUFFLES         # ← power-based cap

out_dir = BASE_OUT / f"{N_PLAYERS}_players"
out_dir.mkdir(exist_ok=True)
chkpt   = out_dir / "checkpoint.pkl"
row_dir = out_dir / "rows"

mp.set_start_method("spawn", force=True)    # Windows & Jupyter safe
rt.run_tournament(
    global_seed          = GLOBAL_SEED,
    checkpoint_path      = chkpt,
    n_jobs               = JOBS,
    collect_metrics      = True,
    row_output_directory = row_dir,
)
print(f"✔ finished {N_PLAYERS}-player run → {out_dir}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'import importlib, multiprocessing as mp\nimport farkle.run_tournament as rt\n\nrt = importlib.reload(rt)                   # fresh copy each run\nrt.N_PLAYERS         = N_PLAYERS\nrt.GAMES_PER_SHUFFLE = GAMES_PER_SHUFFLE\nrt.NUM_SHUFFLES      = NUM_SHUFFLES         # ← power-based cap\n\nout_dir = BASE_OUT / f"{N_PLAYERS}_players"\nout_dir.mkdir(exist_ok=True)\nchkpt   = out_dir / "checkpoint.pkl"\nrow_dir = out_dir / "rows"\n\nmp.set_start_method("spawn", force=True)    # Windows & Jupyter safe\nrt.run_tournament(\n    global_seed          = GLOBAL_SEED,\n    checkpoint_path      = chkpt,\n    n_jobs               = JOBS,\n    collect_metrics      = True,\n    row_output_directory = row_dir,\n)\nprint(f"✔ finished {N_PLAYERS}-player run → {out_dir}")\n')
#
# File s:\Libraries\OneDrive\Documents\Code Projects Parent Folder\Code Projects\Farkle Mk II\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2549, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2547 with self.builtin_trap:
#    2548     args = (magic_arg_s, cell)
# -> 2549     result = fn(*args, **kwargs)
#    2551 # The code below prevents the output from being displayed
#    2552 # when using magics with decorator @output_can_be_silenced
#    2553 # when the last Python token in the expression is a ';'.
#    2554 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File s:\Libraries\OneDrive\Documents\Code Projects Parent Folder\Code Projects\Farkle Mk II\.venv\Lib\site-packages\IPython\core\magics\execution.py:1390, in ExecutionMagics.time(self, line, cell, local_ns)
#    1388 st = clock2()
#    1389 try:
# -> 1390     exec(code, glob, local_ns)
#    1391     out = None
#    1392     # multi-line %%time case
#
# File <timed exec>:15
#
# File S:\Libraries\OneDrive\Documents\Code Projects Parent Folder\Code Projects\Farkle Mk II\src\farkle\run_tournament.py:277, in run_tournament(global_seed, checkpoint_path, n_jobs, ckpt_every_sec, collect_metrics, row_output_directory)
#     272     chunk_fn = _run_chunk
#     274 with ProcessPoolExecutor(
#     275     max_workers=n_jobs, initializer=_init_worker, initargs=(strategies,)
#     276 ) as pool:
# --> 277     future_to_index = {pool.submit(chunk_fn, c): i for i, c in enumerate(chunks)}
#     279     for done, fut in enumerate(as_completed(future_to_index), 1):
#     280         result = fut.result()
#
# File C:\Program Files\Python312\Lib\concurrent\futures\process.py:822, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#     819 self._executor_manager_thread_wakeup.wakeup()
#     821 if self._safe_to_dynamically_spawn_children:
# --> 822     self._adjust_process_count()
#     823 self._start_executor_manager_thread()
#     824 return f
#
# File C:\Program Files\Python312\Lib\concurrent\futures\process.py:781, in ProcessPoolExecutor._adjust_process_count(self)
#     773 process_count = len(self._processes)
#     774 if process_count < self._max_workers:
#     775     # Assertion disabled as this codepath is also used to replace a
#     776     # worker that unexpectedly dies, even when using the 'fork' start
#    (...)    779     # we know a thread is running (self._executor_manager_thread).
#     780     #assert self._safe_to_dynamically_spawn_children or not self._executor_manager_thread, 'https://github.com/python/cpython/issues/90622'
# --> 781     self._spawn_process()
#
# File C:\Program Files\Python312\Lib\concurrent\futures\process.py:799, in ProcessPoolExecutor._spawn_process(self)
#     791 def _spawn_process(self):
#     792     p = self._mp_context.Process(
#     793         target=_process_worker,
#     794         args=(self._call_queue,
#    (...)    797               self._initargs,
#     798               self._max_tasks_per_child))
# --> 799     p.start()
#     800     self._processes[p.pid] = p
#
# File C:\Program Files\Python312\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File C:\Program Files\Python312\Lib\multiprocessing\context.py:337, in SpawnProcess._Popen(process_obj)
#     334 @staticmethod
#     335 def _Popen(process_obj):
#     336     from .popen_spawn_win32 import Popen
# --> 337     return Popen(process_obj)
#
# File C:\Program Files\Python312\Lib\multiprocessing\popen_spawn_win32.py:95, in Popen.__init__(self, process_obj)
#      93 try:
#      94     reduction.dump(prep_data, to_child)
# ---> 95     reduction.dump(process_obj, to_child)
#      96 finally:
#      97     set_spawning_popen(None)
#
# File C:\Program Files\Python312\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:
